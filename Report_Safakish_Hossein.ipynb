# %% [markdown]
# # Projektseminar Eingebettete Systeme
# #### Topic: Early warning systems for seizure detection
# #### Winter Semester 2023/24
# #### Hossein Safakish

# %% [markdown]
# ## Introduction

# %% [markdown]
# Epilepsy is a significant neurological condition prevalent worldwide, characterized by abnormal electrical discharges in the brain. The clinical manifestation of this disorder often presents as epileptic seizures, representing prevalent positive signs of brain disturbance. Epilepsy stands as one of the most frequent primary brain disorders globally. Leading factors contributing to epilepsy include vascular issues, traumatic incidents, infections, brain abscesses, tumors, nutritional deficiencies, pyridoxine deficiency, and disorders related to calcium metabolism. Diagnosing epilepsy requires thorough research to enhance our comprehension of the mechanisms underlying epileptic disorders [4].
#
# “An epileptic seizure is a transient occurrence of
# signs and/or symptoms due to abnormal excessive
# or synchronous neuronal activity in the brain.
# Epilepsy is a disorder of the brain characterized
# by an enduring predisposition to generate
# epileptic seizures and by the neurobiologic,
# cognitive, psychological, and social
# consequences of this condition.” [5]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#                                         Figure 1. Occurrence of seizure [1]

# %% [markdown]
# ## Different types of epileptic seizures

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
#                                       Figure 2. Focal and generalized seizure [2]

# %% [markdown]
# ### Focal Seizure
# **Focal onset aware seizures**, formerly known as focal simple onset seizures, are characterized by the individual maintaining awareness of their surroundings and the ongoing events. Despite an inability to move or respond during these episodes, the person retains cognitive awareness throughout [6].
#
# **Focal onset impaired awareness seizures**, formerly labeled as focal complex seizures, involve a partial loss of awareness in the individual during the episode [6].
#
# ### Generalized Seizure
# **Absence seizures** entail a brief loss of awareness, occasionally accompanied by subtle movements like eye blinking or lip smacking, commonly observed in children.
#
# **Tonic seizures** involve the stiffening of muscles, often resulting in the person falling.
#
# **Atonic seizures** manifest as a sudden loss of muscle tone, leading to falls or a drop of the head.
#
# **Clonic seizures** are characterized by rhythmic, jerking muscle movements.
#
# **Myoclonic seizures** are quick, involuntary muscle jerks.
#
# **Tonic-clonic seizures**, also known as grand mal seizures, encompass a combination of tonic (muscle stiffness) and clonic (rhythmic jerking) phases, often associated with a loss of consciousness. [6]
#
#
# - One of the most prevalent neurological disorders.
# - Despite treatment, approximately one-third of individuals with epilepsy continue to experience seizures.
# - The unpredictable nature of seizures and their consequences often leads to heightened anxiety, significantly diminishing the quality of life for affected individuals. [7]

# %% [markdown]
# ## Motivation

# %% [markdown]
# Our goal is to mitigate or ideally prevent seizures through the development of methods for detecting and predicting their occurrence.

# %% [markdown]
# ## State of the art for seizure detection and prediction

# %% [markdown]
# ## Seizure detection and ways

# %% [markdown]
# There are six primary methods for detecting seizures.
# - **Electroencephalography (EEG)**
#
# An electroencephalogram (EEG) is a diagnostic test designed to measure and record the electrical activity of the brain. This procedure entails the placement of small electrodes on the scalp, which detect and amplify the brain's electrical signals. The resultant EEG data offers valuable insights into the functioning of the brain.
# Crucially, EEG serves as a vital tool in assessing abnormal electrical patterns in the brain. It plays a pivotal role in diagnosing and classifying seizures and epilepsy, providing essential information for understanding and managing these neurological conditions [8].
#
# - **Electrocorticography (ECoG)**
#
# Electrocorticography (ECoG) is a neurophysiological technique that entails the placement of an electrode grid directly on the surface of the brain to record electrical activity. In contrast to EEG, during ECoG, the electrode grid is positioned on the exposed brain cortex, enabling more precise and localized recordings of brain activity.
# While ECoG is an invasive procedure with associated potential risks, it offers valuable insights into the dynamics of brain activity. Its application extends to both clinical diagnosis and scientific exploration of the brain's functions, providing a more detailed understanding of neural processes [9].
#
# - **Electrocardiography (ECG)**
#
# A non-invasive medical test used to measure and record the electrical activity of the heart is known as an Electrocardiogram (ECG or EKG). This procedure involves placing electrodes on specific locations on the skin, usually on the chest, arms, and legs, to detect and amplify the electrical signals produced by the heart. Some personal devices, such as smartwatches, now offer ECG monitoring capabilities.
# The ECG provides crucial information about the heart's rhythm, rate, and overall electrical activity, aiding in the assessment of cardiac health [10].There are two types of abnormal activities related to the heart during a seizure **Tachycardia**, characterized by an increased heart rate, is typically observed during complex partial and tonic-clonic seizures. On the other hand, **bradycardia**, indicating a decreased heart rate, is commonly associated with other types of seizures [11].
#
# - **Accelerometry**
#
# Accelerometry is a technique that entails measuring and recording acceleration or movement patterns through accelerometers. These compact sensors detect and quantify changes in velocity or acceleration across multiple directions. Notably, they have been applied in the detection of motor seizures, including tonic-clonic or myoclonic seizures [12].
#
# - **Video detection**
#
# Several models have been devised for seizure detection through video monitoring. Video systems analyze multiple elements to identify seizures. Motion trajectory methods focus on the path of moving objects in space over time, considering factors such as velocity, area, angular speed, and duration. Certain video analysis techniques utilize markers, which are detectable objects worn on joints and extremities of patients [7].
#
# - **Matress sensor**
#
# The MP5 mattress monitor (Medpage Ltd., UK) is specifically designed to identify seizures occurring during sleep. Positioned between the mattress and box spring, its microphone detects tapping and spring noise, with adjustable sensitivity. In a study involving 64 subjects experiencing 8 tonic–clonic seizures each, the system successfully detected 5 events (62.5%). Although it exhibited a poor positive predictive value of 3.3%, its high negative predictive value of 99.8% could offer patients with these seizures a heightened sense of security.
# The Emfit movement monitor (Emfit Ltd., Finland) is a quasipiezoelectric seizure detector placed under the mattress system, alerting caregivers to unexpected motor activity. Additionally, the system includes a bedside monitor. In a trial involving 22 patients, the Emfit system successfully detected 80% of seizures [7].

# %% [markdown]
# ## Advantages and Disadvantages of the ways

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
#                                 Table 1. Advantages and Disadvantages of the ways [7]

# %% [markdown]
# ## Seizure Prediction
# The potential advantages of predicting seizures surpass those of merely detecting them. Such predictive devices hold promise in preventing accidents and enhancing overall outcomes, enabling early treatment or even the prevention of seizures. In a survey involving 141 patients with epilepsy, over 90% of respondents emphasized the importance of developing means for predicting seizures. Interestingly, these patients expressed a preference for sensitivity over specificity in seizure prediction [13].
#
# For effective prediction, systems must be capable of identifying preictal changes that, if present, occur within minutes, hours, or days before seizures. It's crucial to note that the features used for predicting seizures in advance may or may not be the same as those employed for detecting the presence of a seizure [7].

# %% [markdown]
# ## Combined ways

# %% [markdown]
# Combining multiple approaches can significantly enhance accuracy and specificity in mitigating problems associated with seizure prediction and detection. Three effective ways of such integration include:
#
# 1. **Combined EEG:**
#    - Single EEG Channel: Utilizing a single EEG channel for monitoring electrical brain activity.
#    - Multiple EEG Channels: Employing multiple EEG channels to capture a more comprehensive view of brain signals, enhancing the accuracy of detection [7].
#
# 2. **EEG and ECG:**
#    - Integrating both Electroencephalogram (EEG) and Electrocardiogram (ECG) data for a holistic approach. This combination provides a more thorough understanding of both brain and heart activities, aiding in accurate prediction and detection [7].
#
# 3. **Accelerometry and Electrodermal:**
#    - Combining data from Accelerometry, which measures movement patterns, and Electrodermal activity, which monitors changes in skin conductance. This integration offers a multi-modal approach, capturing diverse physiological indicators and improving overall prediction accuracy [7].
#
# By integrating these different modalities, we can leverage complementary information from various physiological signals, resulting in a more robust and accurate system for mitigating problems associated with seizures. [7]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#                                          Figure 3. Combined EEG and ECG [3]

# %% [markdown]
# ## Closed-loop systems

# %% [markdown]
# Medical closed-loop systems are engineered to autonomously adjust and regulate a designated medical parameter in response to real-time feedback from the patient's physiological signals. These systems maintain continuous monitoring of the patient's condition and, based on the acquired data, deliver appropriate interventions or treatments.
#
# In the realm of neurological conditions, closed-loop neurostimulation systems play a pivotal role, particularly in the treatment of conditions like epilepsy or movement disorders. These sophisticated systems constantly monitor brain activity or specific neural signals and, in turn, administer targeted electrical stimulation. The objective is to modulate or suppress abnormal brain activity, with the overarching goal of reducing seizure frequency or controlling motor symptoms effectively. [7]
#
# **It has four main parts:**
#
# **1. Measuring device**
#
# In a closed-loop system, the continuous collection and processing of reliable and reproducible data are crucial for effective operation. Various sensor and detector tools, as previously discussed in the context of seizure detection, play a pivotal role in acquiring accurate data essential for the closed-loop system's functionality.
#
# The selection of suitable sensors and detectors depends on the specific requirements of the closed-loop system. These tools encompass a range of devices such as EEG (Electroencephalogram), ECG (Electrocardiogram), accelerometers, and other specialized instruments designed for measuring specific physiological parameters. The meticulous choice of these devices ensures that the closed-loop system receives precise and relevant data, facilitating its ability to respond appropriately to the patient's physiological signals. [7]
#
# **2. Data transmission**
#
# Following data acquisition, the information must be transmitted to a system for analysis and processing. In experimental models of closed-loop systems, successful data transmission has been achieved using wireless technologies such as Wi-Fi and Bluetooth.
#
# In the case of certain newer EEG headsets, signal processing, feature calculation, and classification can be executed directly on the device itself. This approach eliminates the need for transmitting raw data, streamlining the process.
#
# From a security perspective, it is imperative to safeguard data transmission to prevent interception and protect patient privacy. Secure standards and protocols have been developed to ensure the encryption and restricted access of transmitted data.
#
# In summary, ensuring rapid, secure, and reliable data transmission is pivotal for closed-loop systems. This facilitates accurate analysis, timely responses, and ultimately contributes to improved patient care. [7]
#
# **3. Data processing**
#
# In closed-loop systems, data processing holds a pivotal role in interpreting signals collected by biometric devices and assessing the patient's seizure risk in real-time. The data processing systems need to efficiently and rapidly determine the patient's current status and the likelihood of imminent or ongoing seizures.
#
# Methods like feature calculation and classification, as discussed earlier and utilizing data from EEG, ECG, and accelerometry, exemplify the data processing systems essential for closed-loop operations. The efficacy of a data processing system is assessed based on parameters such as sensitivity, specificity, and predictive values.
#
# While the steps and algorithms used in closed-loop systems bear similarities to those in seizure prediction systems, the processing time requirements are typically more stringent. The need for quick processing arises from the imperative to promptly activate interventions, aiming to prevent seizures or provide timely warnings. This emphasis on speed is crucial for the overall effectiveness of closed-loop systems in managing and mitigating neurological events. [7]
#
# **4. Response system**
#
# Closed-loop devices in epilepsy exhibit diverse response mechanisms, serving to warn patients or caregivers, initiate activities like medication administration or neurostimulation, and even notify healthcare providers or emergency services. Examples of such devices include the SmartWatch and EpiLert, designed to alert caregivers.
#
# Responsive neurostimulation systems (RNS) are capable of detecting abnormal brain activity and responding by delivering electrical pulses to normalize it. On the other hand, deep brain stimulation (DBS) targets specific parts of the brain for modulation.
#
# A dependable seizure prediction system holds the potential to enable the aborting of imminent seizures using rapid-acting benzodiazepines or other innovative techniques. These may include the use of Peltier coolers, UV light, or local drug delivery systems. The incorporation of such responsive mechanisms enhances the overall effectiveness of closed-loop systems in managing epilepsy and improving patient outcomes. [7]

# %% [markdown]
# # Practical work
# The diagnosis of epilepsy relies significantly on the electroencephalogram (EEG), a critical tool for accurately classifying different forms of epilepsy and facilitating the evaluation and treatment of neurophysiological disorders.
#
# ## Method Selection
# I implemented the dataset using Support Vector Machines (SVM), Deep Neural Networks (DNN), and Convolutional Neural Networks (CNN), and I obtained the results for each of them.
#
# ## About Dataset
# This dataset is a pre-processed and re-structured/reshaped version of a very commonly used dataset featuring epileptic seizure detection [14][15][16][17].
#
# ## Attribute Information
# The original dataset, as referenced, comprises 5 folders, each containing 100 files, with each file representing the brain activity recording of a single subject. These recordings span 23.6 seconds and are sampled into 4097 data points. Consequently, there are a total of 500 individuals, each contributing 4097 data points for a duration of 23.5 seconds.
#
# To enhance the dataset's organization, we partitioned and shuffled every 4097 data points into 23 chunks. Each chunk consists of 178 data points, representing a 1-second interval. Therefore, the dataset now comprises 11,500 entries (rows), each containing 178 data points for 1 second (columns). The final column denotes the label "y" with values {1, 2, 3, 4, 5}.
#
# In summary, the response variable "y" is found in column 179, while the explanatory variables X1, X2, …, X178 provide the EEG recording values at different time points [18].
#
# ## y Definition
# The variable "y" denotes the category of the 178-dimensional input vector and specifically takes values in {1, 2, 3, 4, 5}, each corresponding to different conditions:
#
# - 5: Eyes open, indicating the EEG signal recording when the patient had their eyes open.
# - 4: Eyes closed, representing the EEG signal recording when the patient had their eyes closed.
# - 3: Identification of the tumor region in the brain, recording EEG activity from the healthy brain area.
# - 2: EEG recorded from the area where the tumor was located.
# - 1: Recording of seizure activity.
#
# Subjects falling into classes 2, 3, 4, and 5 are those without epileptic seizures, while subjects in class 1 experience epileptic seizures. Despite the existence of five classes, many authors have simplified the classification task to binary, focusing on class 1 (Epileptic seizure) versus the rest. The motivation behind creating this dataset version in a .csv format is to streamline data access [18].
#
# ## Reference of datastet
# This Dataset collect from UCI Machine Learning Repository (from the University of Bonn) [14][15][16][17][18].
#
# ## Import Libraries

# %%
import time
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.svm import SVC
import matplotlib.pyplot as plt
from keras.models import Sequential
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
# Out:
# WARNING:tensorflow:From C:\Users\hosei\anaconda3\envs\tensorjoon\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## Load the data

# %%
data = pd.read_csv('Epileptic Seizure Recognition.csv')

# %% [markdown]
# ## Show the dataset

# %%
data.head()
# Out:
#       Unnamed   X1   X2   X3   X4   X5   X6   X7   X8   X9  ...  X170  X171  \
# 0  X21.V1.791  135  190  229  223  192  125   55   -9  -33  ...   -17   -15
# 1  X15.V1.924  386  382  356  331  320  315  307  272  244  ...   164   150
# 2     X8.V1.1  -32  -39  -47  -37  -32  -36  -57  -73  -85  ...    57    64
# 3   X16.V1.60 -105 -101  -96  -92  -89  -95 -102 -100  -87  ...   -82   -81
# 4   X20.V1.54   -9  -65  -98 -102  -78  -48  -16    0  -21  ...     4     2
#
#    X172  X173  X174  X175  X176  X177  X178  y
# 0   -31   -77  -103  -127  -116   -83   -51  4
# 1   146   152   157   156   154   143   129  1
# 2    48    19   -12   -30   -35   -35   -36  5
# 3   -80   -77   -85   -77   -72   -69   -65  5
# 4   -12   -32   -41   -65   -83   -89   -73  5
#
# [5 rows x 180 columns]

# %% [markdown]
# # SVM Model

# %%
X = data.iloc[:, 1:-1].values
y = data.iloc[:, -1:].values
y[y > 1] = 0  # Convert multi-class to binary

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25,
                                            shuffle=True, random_state=42)

# Standardize the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

start_time_1 = time.time()
# Build and train the SVM model
svm_model = SVC(kernel='linear', C=1.0, random_state=42)
svm_model.fit(X_train_scaled, y_train)

start_time_2 = time.time()
# Make predictions on the test set
y_pred = svm_model.predict(X_test_scaled)

#end_time = time.time()
# Calculate and print the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

# Calculate and print classification report
class_report = classification_report(y_test, y_pred)
print("Classification Report:")
print(class_report)

end_time = time.time()
# Calculate and print accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

training_time = end_time - start_time_1
print("Running Time of training:", training_time, "seconds")

predicting_time = end_time - start_time_2
print("Running Time of prediction:", predicting_time, "seconds")
# Out:
# C:\Users\hosei\anaconda3\envs\tensorjoon\lib\site-packages\sklearn\utils\validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Confusion Matrix:
# [[2284    1]
#  [ 518   72]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90      2285
#            1       0.99      0.12      0.22       590
#
#     accuracy                           0.82      2875
#    macro avg       0.90      0.56      0.56      2875
# weighted avg       0.85      0.82      0.76      2875
#
# Accuracy: 0.8194782608695652
# Running Time of training: 128.8979971408844 seconds
# Running Time of prediction: 1.3916847705841064 seconds

# %% [markdown]
# # DNN Model

# %%
# Splitting the data into features (X) and labels (y)
X = data.iloc[:,1:-1].values
X.shape

y = data.iloc[:,-1:].values
y[y>1] = 0
y.shape

# Splitting the Dataset into Training and Test Sets
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,shuffle=True)
X_train.shape,y_test.shape

# Creating the model
def denseBlock(dims,inp) :
    x = tf.keras.layers.BatchNormalization() (inp)
    x = tf.keras.layers.Dense(dims,activation=tf.keras.layers.LeakyReLU(0.2)) (x)
    x = tf.keras.layers.Dropout(0.4) (x)
    x = tf.keras.layers.Dense(dims,activation=tf.keras.layers.LeakyReLU(0.2)) (x)
    x = tf.keras.layers.Dropout(0.4) (x)
    x = tf.keras.layers.Dense(dims,activation=tf.keras.layers.LeakyReLU(0.2)) (x)
    x = tf.keras.layers.Dropout(0.4) (x)
    x = tf.keras.layers.Dense(178,activation=tf.keras.layers.LeakyReLU(0.2)) (x)
    return x

inp = tf.keras.layers.Input(shape=(178,),name='input')
x1 = denseBlock(256,inp)
x2 = denseBlock(512,inp)
x3 = denseBlock(1024,inp)
x = tf.keras.layers.Concatenate()([x1,x2,x3])
x = tf.keras.layers.Dense(128,activation=tf.keras.layers.LeakyReLU(0.2)) (x)
out = tf.keras.layers.Dense(1,activation='sigmoid',name='output') (x)

model = tf.keras.models.Model(inp,out)

# Compiling and Training the Model
sc = StandardScaler()
x_train_scaled = sc.fit_transform(X_train)
x_test_scaled = sc.transform(X_test)

model.compile(loss='binary_crossentropy',optimizer=tf.keras.optimizers.Adam(1e-4),metrics=['accuracy'])

start_time_1 = time.time()
model.fit(X_train,y_train,epochs=150,batch_size=32,validation_split=0.2)

model.evaluate(X_test,y_test)

start_time_2 = time.time()
# Predict on the test set
y_pred = model.predict(x_test_scaled)

# Convert predicted probabilities to binary predictions
y_pred_binary = (y_pred > 0.5).astype(int)

end_time = time.time()

# Calculate and print the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred_binary)
print("Confusion Matrix:")
print(conf_matrix)

# Calculate and print classification report
class_report = classification_report(y_test, y_pred_binary)
print("Classification Report:")
print(class_report)

# Calculate and print accuracy
accuracy2 = accuracy_score(y_test, y_pred_binary)
print("Accuracy:", accuracy2)

# Extract the number of seizure and non-seizure cases from the confusion matrix
seizure_cases = conf_matrix[1, 1]  # True Positives
non_seizure_cases = conf_matrix[0, 0]  # True Negatives

training_time = end_time - start_time_1
print("Running Time of training:", training_time, "seconds")

predicting_time = end_time - start_time_2
print("Running Time of prediction:", predicting_time, "seconds")
# Out:
# Epoch 1/150
# 216/216 [==============================] - 14s 36ms/step - loss: 0.5058 - accuracy: 0.8167 - val_loss: 0.2515 - val_accuracy: 0.9328
# Epoch 2/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.2216 - accuracy: 0.9322 - val_loss: 0.2189 - val_accuracy: 0.9333
# Epoch 3/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.1575 - accuracy: 0.9519 - val_loss: 0.1471 - val_accuracy: 0.9519
# Epoch 4/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.1409 - accuracy: 0.9522 - val_loss: 0.1292 - val_accuracy: 0.9623
# Epoch 5/150
# 216/216 [==============================] - 7s 34ms/step - loss: 0.1396 - accuracy: 0.9546 - val_loss: 0.1318 - val_accuracy: 0.9548
# Epoch 6/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.1270 - accuracy: 0.9561 - val_loss: 0.1332 - val_accuracy: 0.9565
# Epoch 7/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.1140 - accuracy: 0.9601 - val_loss: 0.1122 - val_accuracy: 0.9641
# Epoch 8/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.1140 - accuracy: 0.9594 - val_loss: 0.1255 - val_accuracy: 0.9606
# Epoch 9/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.1018 - accuracy: 0.9636 - val_loss: 0.1450 - val_accuracy: 0.9594
# Epoch 10/150
# 216/216 [==============================] - 7s 34ms/step - loss: 0.1098 - accuracy: 0.9600 - val_loss: 0.1480 - val_accuracy: 0.9530
# Epoch 11/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0941 - accuracy: 0.9672 - val_loss: 0.1420 - val_accuracy: 0.9571
# Epoch 12/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0981 - accuracy: 0.9638 - val_loss: 0.1215 - val_accuracy: 0.9600
# Epoch 13/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0867 - accuracy: 0.9686 - val_loss: 0.1047 - val_accuracy: 0.9646
# Epoch 14/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0917 - accuracy: 0.9655 - val_loss: 0.1234 - val_accuracy: 0.9617
# Epoch 15/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0885 - accuracy: 0.9688 - val_loss: 0.1070 - val_accuracy: 0.9670
# Epoch 16/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0854 - accuracy: 0.9677 - val_loss: 0.1224 - val_accuracy: 0.9612
# Epoch 17/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0835 - accuracy: 0.9703 - val_loss: 0.1553 - val_accuracy: 0.9565
# Epoch 18/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0763 - accuracy: 0.9732 - val_loss: 0.1386 - val_accuracy: 0.9617
# Epoch 19/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0791 - accuracy: 0.9710 - val_loss: 0.1301 - val_accuracy: 0.9617
# Epoch 20/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0728 - accuracy: 0.9742 - val_loss: 0.1345 - val_accuracy: 0.9588
# Epoch 21/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0771 - accuracy: 0.9713 - val_loss: 0.1455 - val_accuracy: 0.9565
# Epoch 22/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0701 - accuracy: 0.9746 - val_loss: 0.1085 - val_accuracy: 0.9641
# Epoch 23/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0771 - accuracy: 0.9728 - val_loss: 0.1047 - val_accuracy: 0.9664
# Epoch 24/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0739 - accuracy: 0.9736 - val_loss: 0.1375 - val_accuracy: 0.9588
# Epoch 25/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0677 - accuracy: 0.9729 - val_loss: 0.1387 - val_accuracy: 0.9623
# Epoch 26/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0720 - accuracy: 0.9736 - val_loss: 0.1149 - val_accuracy: 0.9658
# Epoch 27/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0646 - accuracy: 0.9742 - val_loss: 0.1429 - val_accuracy: 0.9629
# Epoch 28/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0692 - accuracy: 0.9761 - val_loss: 0.1159 - val_accuracy: 0.9617
# Epoch 29/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0711 - accuracy: 0.9729 - val_loss: 0.1292 - val_accuracy: 0.9612
# Epoch 30/150
# 216/216 [==============================] - 7s 35ms/step - loss: 0.0648 - accuracy: 0.9754 - val_loss: 0.1107 - val_accuracy: 0.9681
# Epoch 31/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0642 - accuracy: 0.9758 - val_loss: 0.1600 - val_accuracy: 0.9565
# Epoch 32/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0722 - accuracy: 0.9738 - val_loss: 0.1006 - val_accuracy: 0.9629
# Epoch 33/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0720 - accuracy: 0.9732 - val_loss: 0.1137 - val_accuracy: 0.9658
# Epoch 34/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0663 - accuracy: 0.9765 - val_loss: 0.1080 - val_accuracy: 0.9635
# Epoch 35/150
# 216/216 [==============================] - 7s 34ms/step - loss: 0.0664 - accuracy: 0.9759 - val_loss: 0.1138 - val_accuracy: 0.9606
# Epoch 36/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0660 - accuracy: 0.9742 - val_loss: 0.1412 - val_accuracy: 0.9588
# Epoch 37/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0632 - accuracy: 0.9770 - val_loss: 0.1444 - val_accuracy: 0.9623
# Epoch 38/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0579 - accuracy: 0.9791 - val_loss: 0.1621 - val_accuracy: 0.9606
# Epoch 39/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0634 - accuracy: 0.9761 - val_loss: 0.1245 - val_accuracy: 0.9635
# Epoch 40/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0647 - accuracy: 0.9761 - val_loss: 0.1220 - val_accuracy: 0.9606
# Epoch 41/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0570 - accuracy: 0.9784 - val_loss: 0.1065 - val_accuracy: 0.9641
# Epoch 42/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0567 - accuracy: 0.9786 - val_loss: 0.1371 - val_accuracy: 0.9641
# Epoch 43/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0620 - accuracy: 0.9781 - val_loss: 0.1201 - val_accuracy: 0.9617
# Epoch 44/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0525 - accuracy: 0.9790 - val_loss: 0.1269 - val_accuracy: 0.9658
# Epoch 45/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0564 - accuracy: 0.9786 - val_loss: 0.1205 - val_accuracy: 0.9664
# Epoch 46/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0610 - accuracy: 0.9772 - val_loss: 0.1397 - val_accuracy: 0.9629
# Epoch 47/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0512 - accuracy: 0.9794 - val_loss: 0.1093 - val_accuracy: 0.9687
# Epoch 48/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0581 - accuracy: 0.9803 - val_loss: 0.1178 - val_accuracy: 0.9670
# Epoch 49/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0470 - accuracy: 0.9825 - val_loss: 0.1407 - val_accuracy: 0.9658
# Epoch 50/150
# 216/216 [==============================] - 7s 34ms/step - loss: 0.0497 - accuracy: 0.9826 - val_loss: 0.1301 - val_accuracy: 0.9635
# Epoch 51/150
# 216/216 [==============================] - 7s 34ms/step - loss: 0.0527 - accuracy: 0.9791 - val_loss: 0.1173 - val_accuracy: 0.9652
# Epoch 52/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0503 - accuracy: 0.9803 - val_loss: 0.1327 - val_accuracy: 0.9670
# Epoch 53/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0495 - accuracy: 0.9823 - val_loss: 0.0967 - val_accuracy: 0.9722
# Epoch 54/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0558 - accuracy: 0.9786 - val_loss: 0.1308 - val_accuracy: 0.9641
# Epoch 55/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0555 - accuracy: 0.9796 - val_loss: 0.1591 - val_accuracy: 0.9600
# Epoch 56/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0612 - accuracy: 0.9780 - val_loss: 0.1199 - val_accuracy: 0.9658
# Epoch 57/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0485 - accuracy: 0.9806 - val_loss: 0.1286 - val_accuracy: 0.9658
# Epoch 58/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0488 - accuracy: 0.9816 - val_loss: 0.1432 - val_accuracy: 0.9623
# Epoch 59/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0450 - accuracy: 0.9842 - val_loss: 0.1169 - val_accuracy: 0.9687
# Epoch 60/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0435 - accuracy: 0.9839 - val_loss: 0.1241 - val_accuracy: 0.9693
# Epoch 61/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0537 - accuracy: 0.9793 - val_loss: 0.1089 - val_accuracy: 0.9664
# Epoch 62/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0542 - accuracy: 0.9820 - val_loss: 0.1201 - val_accuracy: 0.9658
# Epoch 63/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0581 - accuracy: 0.9794 - val_loss: 0.1230 - val_accuracy: 0.9687
# Epoch 64/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0425 - accuracy: 0.9843 - val_loss: 0.1063 - val_accuracy: 0.9710
# Epoch 65/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0449 - accuracy: 0.9839 - val_loss: 0.1533 - val_accuracy: 0.9617
# Epoch 66/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0459 - accuracy: 0.9842 - val_loss: 0.1290 - val_accuracy: 0.9670
# Epoch 67/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0410 - accuracy: 0.9859 - val_loss: 0.1430 - val_accuracy: 0.9646
# Epoch 68/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0419 - accuracy: 0.9854 - val_loss: 0.1319 - val_accuracy: 0.9652
# Epoch 69/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0394 - accuracy: 0.9858 - val_loss: 0.1471 - val_accuracy: 0.9652
# Epoch 70/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0473 - accuracy: 0.9820 - val_loss: 0.1188 - val_accuracy: 0.9693
# Epoch 71/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0499 - accuracy: 0.9803 - val_loss: 0.1383 - val_accuracy: 0.9635
# Epoch 72/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0406 - accuracy: 0.9836 - val_loss: 0.1594 - val_accuracy: 0.9623
# Epoch 73/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0447 - accuracy: 0.9828 - val_loss: 0.1213 - val_accuracy: 0.9704
# Epoch 74/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0443 - accuracy: 0.9843 - val_loss: 0.1280 - val_accuracy: 0.9693
# Epoch 75/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0398 - accuracy: 0.9851 - val_loss: 0.1523 - val_accuracy: 0.9635
# Epoch 76/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0438 - accuracy: 0.9833 - val_loss: 0.1497 - val_accuracy: 0.9629
# Epoch 77/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0315 - accuracy: 0.9886 - val_loss: 0.1479 - val_accuracy: 0.9670
# Epoch 78/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0342 - accuracy: 0.9870 - val_loss: 0.1275 - val_accuracy: 0.9670
# Epoch 79/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0417 - accuracy: 0.9851 - val_loss: 0.1478 - val_accuracy: 0.9623
# Epoch 80/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0357 - accuracy: 0.9861 - val_loss: 0.1232 - val_accuracy: 0.9687
# Epoch 81/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0386 - accuracy: 0.9855 - val_loss: 0.1544 - val_accuracy: 0.9612
# Epoch 82/150
# 216/216 [==============================] - 7s 31ms/step - loss: 0.0396 - accuracy: 0.9849 - val_loss: 0.1343 - val_accuracy: 0.9681
# Epoch 83/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0418 - accuracy: 0.9852 - val_loss: 0.1175 - val_accuracy: 0.9693
# Epoch 84/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0376 - accuracy: 0.9851 - val_loss: 0.1244 - val_accuracy: 0.9670
# Epoch 85/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0421 - accuracy: 0.9852 - val_loss: 0.1280 - val_accuracy: 0.9664
# Epoch 86/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0368 - accuracy: 0.9874 - val_loss: 0.1289 - val_accuracy: 0.9641
# Epoch 87/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0435 - accuracy: 0.9830 - val_loss: 0.1227 - val_accuracy: 0.9664
# Epoch 88/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0408 - accuracy: 0.9849 - val_loss: 0.1403 - val_accuracy: 0.9652
# Epoch 89/150
# 216/216 [==============================] - 7s 31ms/step - loss: 0.0399 - accuracy: 0.9852 - val_loss: 0.1225 - val_accuracy: 0.9652
# Epoch 90/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0348 - accuracy: 0.9877 - val_loss: 0.1445 - val_accuracy: 0.9652
# Epoch 91/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0357 - accuracy: 0.9872 - val_loss: 0.1419 - val_accuracy: 0.9658
# Epoch 92/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0349 - accuracy: 0.9871 - val_loss: 0.1408 - val_accuracy: 0.9646
# Epoch 93/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0347 - accuracy: 0.9888 - val_loss: 0.1133 - val_accuracy: 0.9675
# Epoch 94/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0335 - accuracy: 0.9871 - val_loss: 0.1209 - val_accuracy: 0.9681
# Epoch 95/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0288 - accuracy: 0.9887 - val_loss: 0.1201 - val_accuracy: 0.9710
# Epoch 96/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0375 - accuracy: 0.9859 - val_loss: 0.1091 - val_accuracy: 0.9722
# Epoch 97/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0369 - accuracy: 0.9878 - val_loss: 0.1329 - val_accuracy: 0.9704
# Epoch 98/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0329 - accuracy: 0.9868 - val_loss: 0.1417 - val_accuracy: 0.9664
# Epoch 99/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0376 - accuracy: 0.9858 - val_loss: 0.1350 - val_accuracy: 0.9646
# Epoch 100/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0428 - accuracy: 0.9846 - val_loss: 0.1748 - val_accuracy: 0.9588
# Epoch 101/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0352 - accuracy: 0.9870 - val_loss: 0.1584 - val_accuracy: 0.9699
# Epoch 102/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0350 - accuracy: 0.9880 - val_loss: 0.1250 - val_accuracy: 0.9681
# Epoch 103/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0360 - accuracy: 0.9880 - val_loss: 0.1332 - val_accuracy: 0.9641
# Epoch 104/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0334 - accuracy: 0.9887 - val_loss: 0.1278 - val_accuracy: 0.9675
# Epoch 105/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0426 - accuracy: 0.9833 - val_loss: 0.1131 - val_accuracy: 0.9681
# Epoch 106/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0367 - accuracy: 0.9867 - val_loss: 0.1558 - val_accuracy: 0.9617
# Epoch 107/150
# 216/216 [==============================] - 7s 34ms/step - loss: 0.0334 - accuracy: 0.9875 - val_loss: 0.1192 - val_accuracy: 0.9675
# Epoch 108/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0356 - accuracy: 0.9875 - val_loss: 0.1408 - val_accuracy: 0.9629
# Epoch 109/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0335 - accuracy: 0.9868 - val_loss: 0.1110 - val_accuracy: 0.9693
# Epoch 110/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0349 - accuracy: 0.9871 - val_loss: 0.1531 - val_accuracy: 0.9612
# Epoch 111/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0291 - accuracy: 0.9894 - val_loss: 0.1701 - val_accuracy: 0.9623
# Epoch 112/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0256 - accuracy: 0.9904 - val_loss: 0.1414 - val_accuracy: 0.9664
# Epoch 113/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0332 - accuracy: 0.9880 - val_loss: 0.1162 - val_accuracy: 0.9699
# Epoch 114/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0354 - accuracy: 0.9867 - val_loss: 0.1431 - val_accuracy: 0.9699
# Epoch 115/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0364 - accuracy: 0.9862 - val_loss: 0.1331 - val_accuracy: 0.9635
# Epoch 116/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0347 - accuracy: 0.9883 - val_loss: 0.1083 - val_accuracy: 0.9693
# Epoch 117/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0305 - accuracy: 0.9887 - val_loss: 0.1611 - val_accuracy: 0.9641
# Epoch 118/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0239 - accuracy: 0.9916 - val_loss: 0.1418 - val_accuracy: 0.9681
# Epoch 119/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0309 - accuracy: 0.9888 - val_loss: 0.1281 - val_accuracy: 0.9670
# Epoch 120/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0314 - accuracy: 0.9890 - val_loss: 0.1199 - val_accuracy: 0.9733
# Epoch 121/150
# 216/216 [==============================] - 7s 31ms/step - loss: 0.0287 - accuracy: 0.9906 - val_loss: 0.1443 - val_accuracy: 0.9664
# Epoch 122/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0263 - accuracy: 0.9910 - val_loss: 0.1465 - val_accuracy: 0.9658
# Epoch 123/150
# 216/216 [==============================] - 7s 31ms/step - loss: 0.0326 - accuracy: 0.9883 - val_loss: 0.1247 - val_accuracy: 0.9670
# Epoch 124/150
# 216/216 [==============================] - 7s 31ms/step - loss: 0.0305 - accuracy: 0.9896 - val_loss: 0.1267 - val_accuracy: 0.9670
# Epoch 125/150
# 216/216 [==============================] - 7s 31ms/step - loss: 0.0272 - accuracy: 0.9904 - val_loss: 0.1296 - val_accuracy: 0.9664
# Epoch 126/150
# 216/216 [==============================] - 7s 31ms/step - loss: 0.0314 - accuracy: 0.9883 - val_loss: 0.1308 - val_accuracy: 0.9670
# Epoch 127/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0304 - accuracy: 0.9874 - val_loss: 0.1271 - val_accuracy: 0.9716
# Epoch 128/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0288 - accuracy: 0.9897 - val_loss: 0.1683 - val_accuracy: 0.9617
# Epoch 129/150
# 216/216 [==============================] - 7s 34ms/step - loss: 0.0345 - accuracy: 0.9878 - val_loss: 0.1288 - val_accuracy: 0.9670
# Epoch 130/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0237 - accuracy: 0.9906 - val_loss: 0.1456 - val_accuracy: 0.9664
# Epoch 131/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0283 - accuracy: 0.9907 - val_loss: 0.1465 - val_accuracy: 0.9652
# Epoch 132/150
# 216/216 [==============================] - 7s 34ms/step - loss: 0.0225 - accuracy: 0.9907 - val_loss: 0.1503 - val_accuracy: 0.9652
# Epoch 133/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0334 - accuracy: 0.9875 - val_loss: 0.1103 - val_accuracy: 0.9733
# Epoch 134/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0278 - accuracy: 0.9900 - val_loss: 0.1473 - val_accuracy: 0.9664
# Epoch 135/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0246 - accuracy: 0.9907 - val_loss: 0.1578 - val_accuracy: 0.9641
# Epoch 136/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0246 - accuracy: 0.9900 - val_loss: 0.1504 - val_accuracy: 0.9652
# Epoch 137/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0268 - accuracy: 0.9890 - val_loss: 0.1357 - val_accuracy: 0.9670
# Epoch 138/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0274 - accuracy: 0.9913 - val_loss: 0.1407 - val_accuracy: 0.9646
# Epoch 139/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0295 - accuracy: 0.9887 - val_loss: 0.1392 - val_accuracy: 0.9681
# Epoch 140/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0284 - accuracy: 0.9907 - val_loss: 0.1883 - val_accuracy: 0.9600
# Epoch 141/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0299 - accuracy: 0.9890 - val_loss: 0.1483 - val_accuracy: 0.9641
# Epoch 142/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0246 - accuracy: 0.9909 - val_loss: 0.1516 - val_accuracy: 0.9629
# Epoch 143/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0230 - accuracy: 0.9913 - val_loss: 0.1286 - val_accuracy: 0.9687
# Epoch 144/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0240 - accuracy: 0.9919 - val_loss: 0.1265 - val_accuracy: 0.9704
# Epoch 145/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0232 - accuracy: 0.9913 - val_loss: 0.1613 - val_accuracy: 0.9658
# Epoch 146/150
# 216/216 [==============================] - 7s 33ms/step - loss: 0.0301 - accuracy: 0.9874 - val_loss: 0.2039 - val_accuracy: 0.9617
# Epoch 147/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0258 - accuracy: 0.9910 - val_loss: 0.1577 - val_accuracy: 0.9687
# Epoch 148/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0252 - accuracy: 0.9912 - val_loss: 0.1287 - val_accuracy: 0.9704
# Epoch 149/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0199 - accuracy: 0.9926 - val_loss: 0.1521 - val_accuracy: 0.9693
# Epoch 150/150
# 216/216 [==============================] - 7s 32ms/step - loss: 0.0263 - accuracy: 0.9903 - val_loss: 0.1900 - val_accuracy: 0.9606
# 90/90 [==============================] - 1s 8ms/step - loss: 0.1642 - accuracy: 0.9610
# 90/90 [==============================] - 1s 8ms/step
# Confusion Matrix:
# [[2332    0]
#  [ 543    0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.90      2332
#            1       0.00      0.00      0.00       543
#
#     accuracy                           0.81      2875
#    macro avg       0.41      0.50      0.45      2875
# weighted avg       0.66      0.81      0.73      2875
#
# Accuracy: 0.8111304347826087
# Running Time of training: 1054.449355840683 seconds
# Running Time of prediction: 1.4050285816192627 seconds
# C:\Users\hosei\anaconda3\envs\tensorjoon\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\hosei\anaconda3\envs\tensorjoon\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\hosei\anaconda3\envs\tensorjoon\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # CNN Model

# %%
X = data.iloc[:, 1:-1].values
y = data.iloc[:, -1:].values
y[y > 1] = 0  # Convert multi-class to binary

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, shuffle=True, random_state=42)

# Standardize the data

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Reshape the data for CNN
X_train_reshaped = X_train_scaled.reshape(X_train_scaled.shape[0], X_train_scaled.shape[1], 1)
X_test_reshaped = X_test_scaled.reshape(X_test_scaled.shape[0], X_test_scaled.shape[1], 1)

# Build the CNN model
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train_reshaped.shape[1], 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

start_time_1 = time.time()
# Train the model
history = model.fit(X_train_reshaped, y_train, epochs=150, batch_size=32, validation_split=0.2)

# Evaluate the model
start_time_2 = time.time()

y_pred = model.predict(X_test_reshaped)
y_pred_binary = (y_pred > 0.5).astype(int)

# Calculate and print the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred_binary)
print("Confusion Matrix:")
print(conf_matrix)

# Calculate and print classification report
class_report = classification_report(y_test, y_pred_binary)
print("Classification Report:")
print(class_report)

# Calculate and print accuracy
accuracy3 = accuracy_score(y_test, y_pred_binary)
print("Accuracy:", accuracy3)

# Calculate and print running time

training_time = end_time - start_time_1
print("Running Time of training:", training_time, "seconds")

predicting_time = end_time - start_time_2
print("Running Time of prediction:", predicting_time, "seconds")

# Plot training history
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# WARNING:tensorflow:From C:\Users\hosei\anaconda3\envs\tensorjoon\lib\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\hosei\anaconda3\envs\tensorjoon\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/150
# 216/216 [==============================] - 6s 19ms/step - loss: 0.1698 - accuracy: 0.9342 - val_loss: 0.1129 - val_accuracy: 0.9484
# Epoch 2/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.1029 - accuracy: 0.9572 - val_loss: 0.1186 - val_accuracy: 0.9525
# Epoch 3/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0905 - accuracy: 0.9616 - val_loss: 0.1075 - val_accuracy: 0.9548
# Epoch 4/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0818 - accuracy: 0.9651 - val_loss: 0.1050 - val_accuracy: 0.9617
# Epoch 5/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0692 - accuracy: 0.9696 - val_loss: 0.0837 - val_accuracy: 0.9687
# Epoch 6/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0588 - accuracy: 0.9775 - val_loss: 0.0757 - val_accuracy: 0.9704
# Epoch 7/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0491 - accuracy: 0.9814 - val_loss: 0.0789 - val_accuracy: 0.9774
# Epoch 8/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0396 - accuracy: 0.9857 - val_loss: 0.0737 - val_accuracy: 0.9780
# Epoch 9/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0369 - accuracy: 0.9855 - val_loss: 0.0718 - val_accuracy: 0.9757
# Epoch 10/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0317 - accuracy: 0.9899 - val_loss: 0.0754 - val_accuracy: 0.9768
# Epoch 11/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0242 - accuracy: 0.9917 - val_loss: 0.0715 - val_accuracy: 0.9751
# Epoch 12/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0184 - accuracy: 0.9935 - val_loss: 0.0728 - val_accuracy: 0.9786
# Epoch 13/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0172 - accuracy: 0.9948 - val_loss: 0.0803 - val_accuracy: 0.9791
# Epoch 14/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0163 - accuracy: 0.9945 - val_loss: 0.0755 - val_accuracy: 0.9786
# Epoch 15/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0143 - accuracy: 0.9948 - val_loss: 0.0731 - val_accuracy: 0.9791
# Epoch 16/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0160 - accuracy: 0.9941 - val_loss: 0.0776 - val_accuracy: 0.9809
# Epoch 17/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0152 - accuracy: 0.9951 - val_loss: 0.0734 - val_accuracy: 0.9803
# Epoch 18/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0130 - accuracy: 0.9951 - val_loss: 0.1011 - val_accuracy: 0.9762
# Epoch 19/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0160 - accuracy: 0.9945 - val_loss: 0.0798 - val_accuracy: 0.9832
# Epoch 20/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0075 - accuracy: 0.9978 - val_loss: 0.0982 - val_accuracy: 0.9803
# Epoch 21/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0085 - accuracy: 0.9974 - val_loss: 0.0790 - val_accuracy: 0.9780
# Epoch 22/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0097 - accuracy: 0.9965 - val_loss: 0.0869 - val_accuracy: 0.9797
# Epoch 23/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0076 - accuracy: 0.9970 - val_loss: 0.0944 - val_accuracy: 0.9826
# Epoch 24/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0066 - accuracy: 0.9978 - val_loss: 0.1402 - val_accuracy: 0.9768
# Epoch 25/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0087 - accuracy: 0.9971 - val_loss: 0.0803 - val_accuracy: 0.9855
# Epoch 26/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0074 - accuracy: 0.9978 - val_loss: 0.0887 - val_accuracy: 0.9832
# Epoch 27/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0052 - accuracy: 0.9987 - val_loss: 0.0864 - val_accuracy: 0.9843
# Epoch 28/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 0.1419 - val_accuracy: 0.9797
# Epoch 29/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0066 - accuracy: 0.9978 - val_loss: 0.1105 - val_accuracy: 0.9820
# Epoch 30/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0082 - accuracy: 0.9971 - val_loss: 0.0874 - val_accuracy: 0.9814
# Epoch 31/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0059 - accuracy: 0.9978 - val_loss: 0.1147 - val_accuracy: 0.9803
# Epoch 32/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0082 - accuracy: 0.9978 - val_loss: 0.0918 - val_accuracy: 0.9832
# Epoch 33/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0035 - accuracy: 0.9987 - val_loss: 0.1100 - val_accuracy: 0.9809
# Epoch 34/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0044 - accuracy: 0.9980 - val_loss: 0.1112 - val_accuracy: 0.9803
# Epoch 35/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0046 - accuracy: 0.9987 - val_loss: 0.1017 - val_accuracy: 0.9826
# Epoch 36/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0047 - accuracy: 0.9987 - val_loss: 0.0982 - val_accuracy: 0.9843
# Epoch 37/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0050 - accuracy: 0.9980 - val_loss: 0.1528 - val_accuracy: 0.9780
# Epoch 38/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0110 - accuracy: 0.9964 - val_loss: 0.1509 - val_accuracy: 0.9797
# Epoch 39/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0080 - accuracy: 0.9965 - val_loss: 0.1181 - val_accuracy: 0.9820
# Epoch 40/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0053 - accuracy: 0.9984 - val_loss: 0.1771 - val_accuracy: 0.9768
# Epoch 41/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0053 - accuracy: 0.9981 - val_loss: 0.1190 - val_accuracy: 0.9820
# Epoch 42/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0062 - accuracy: 0.9987 - val_loss: 0.1011 - val_accuracy: 0.9814
# Epoch 43/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.1563 - val_accuracy: 0.9791
# Epoch 44/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0057 - accuracy: 0.9986 - val_loss: 0.1110 - val_accuracy: 0.9820
# Epoch 45/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0032 - accuracy: 0.9993 - val_loss: 0.1286 - val_accuracy: 0.9820
# Epoch 46/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.1720 - val_accuracy: 0.9809
# Epoch 47/150
# 216/216 [==============================] - 4s 16ms/step - loss: 0.0070 - accuracy: 0.9967 - val_loss: 0.1209 - val_accuracy: 0.9826
# Epoch 48/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.1199 - val_accuracy: 0.9867
# Epoch 49/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0032 - accuracy: 0.9988 - val_loss: 0.1068 - val_accuracy: 0.9832
# Epoch 50/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.1272 - val_accuracy: 0.9861
# Epoch 51/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0021 - accuracy: 0.9991 - val_loss: 0.1129 - val_accuracy: 0.9861
# Epoch 52/150
# 216/216 [==============================] - 4s 16ms/step - loss: 0.0029 - accuracy: 0.9988 - val_loss: 0.1410 - val_accuracy: 0.9814
# Epoch 53/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.1463 - val_accuracy: 0.9814
# Epoch 54/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.1484 - val_accuracy: 0.9826
# Epoch 55/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0018 - accuracy: 0.9990 - val_loss: 0.1543 - val_accuracy: 0.9838
# Epoch 56/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.1354 - val_accuracy: 0.9878
# Epoch 57/150
# 216/216 [==============================] - 3s 15ms/step - loss: 0.0029 - accuracy: 0.9996 - val_loss: 0.1230 - val_accuracy: 0.9855
# Epoch 58/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0163 - accuracy: 0.9962 - val_loss: 0.1810 - val_accuracy: 0.9814
# Epoch 59/150
# 216/216 [==============================] - 4s 18ms/step - loss: 0.0097 - accuracy: 0.9970 - val_loss: 0.1149 - val_accuracy: 0.9843
# Epoch 60/150
# 216/216 [==============================] - 4s 18ms/step - loss: 0.0086 - accuracy: 0.9970 - val_loss: 0.1051 - val_accuracy: 0.9838
# Epoch 61/150
# 216/216 [==============================] - 4s 18ms/step - loss: 0.0032 - accuracy: 0.9988 - val_loss: 0.1304 - val_accuracy: 0.9855
# Epoch 62/150
# 216/216 [==============================] - 4s 18ms/step - loss: 0.0055 - accuracy: 0.9988 - val_loss: 0.1557 - val_accuracy: 0.9803
# Epoch 63/150
# 216/216 [==============================] - 4s 18ms/step - loss: 0.0022 - accuracy: 0.9991 - val_loss: 0.1485 - val_accuracy: 0.9843
# Epoch 64/150
# 216/216 [==============================] - 4s 18ms/step - loss: 8.9963e-04 - accuracy: 0.9997 - val_loss: 0.1437 - val_accuracy: 0.9826
# Epoch 65/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.1694 - val_accuracy: 0.9814
# Epoch 66/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.1783 - val_accuracy: 0.9791
# Epoch 67/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.1771 - val_accuracy: 0.9797
# Epoch 68/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0042 - accuracy: 0.9986 - val_loss: 0.0981 - val_accuracy: 0.9855
# Epoch 69/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.1278 - val_accuracy: 0.9849
# Epoch 70/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.1252 - val_accuracy: 0.9843
# Epoch 71/150
# 216/216 [==============================] - 4s 16ms/step - loss: 0.0046 - accuracy: 0.9986 - val_loss: 0.0898 - val_accuracy: 0.9843
# Epoch 72/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.1185 - val_accuracy: 0.9849
# Epoch 73/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.1703 - val_accuracy: 0.9786
# Epoch 74/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.1296 - val_accuracy: 0.9814
# Epoch 75/150
# 216/216 [==============================] - 4s 17ms/step - loss: 6.9646e-04 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9814
# Epoch 76/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0030 - accuracy: 0.9986 - val_loss: 0.1695 - val_accuracy: 0.9814
# Epoch 77/150
# 216/216 [==============================] - 4s 16ms/step - loss: 3.2600e-04 - accuracy: 1.0000 - val_loss: 0.1714 - val_accuracy: 0.9838
# Epoch 78/150
# 216/216 [==============================] - 3s 15ms/step - loss: 9.9345e-04 - accuracy: 0.9997 - val_loss: 0.1259 - val_accuracy: 0.9820
# Epoch 79/150
# 216/216 [==============================] - 3s 16ms/step - loss: 0.0206 - accuracy: 0.9954 - val_loss: 0.1342 - val_accuracy: 0.9838
# Epoch 80/150
# 216/216 [==============================] - 4s 16ms/step - loss: 0.0060 - accuracy: 0.9984 - val_loss: 0.1496 - val_accuracy: 0.9867
# Epoch 81/150
# 216/216 [==============================] - 4s 16ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.1439 - val_accuracy: 0.9849
# Epoch 82/150
# 216/216 [==============================] - 4s 16ms/step - loss: 0.0033 - accuracy: 0.9993 - val_loss: 0.1334 - val_accuracy: 0.9838
# Epoch 83/150
# 216/216 [==============================] - 4s 16ms/step - loss: 0.0034 - accuracy: 0.9988 - val_loss: 0.1561 - val_accuracy: 0.9832
# Epoch 84/150
# 216/216 [==============================] - 4s 16ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.1089 - val_accuracy: 0.9843
# Epoch 85/150
# 216/216 [==============================] - 4s 16ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.1834 - val_accuracy: 0.9838
# Epoch 86/150
# 216/216 [==============================] - 3s 16ms/step - loss: 9.0259e-04 - accuracy: 0.9996 - val_loss: 0.1619 - val_accuracy: 0.9849
# Epoch 87/150
# 216/216 [==============================] - 4s 16ms/step - loss: 3.4929e-04 - accuracy: 0.9999 - val_loss: 0.1591 - val_accuracy: 0.9849
# Epoch 88/150
# 216/216 [==============================] - 4s 16ms/step - loss: 0.0023 - accuracy: 0.9987 - val_loss: 0.1818 - val_accuracy: 0.9826
# Epoch 89/150
# 216/216 [==============================] - 4s 16ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1550 - val_accuracy: 0.9867
# Epoch 90/150
# 216/216 [==============================] - 3s 16ms/step - loss: 9.8855e-04 - accuracy: 0.9994 - val_loss: 0.2407 - val_accuracy: 0.9786
# Epoch 91/150
# 216/216 [==============================] - 4s 16ms/step - loss: 0.0013 - accuracy: 0.9993 - val_loss: 0.1663 - val_accuracy: 0.9878
# Epoch 92/150
# 216/216 [==============================] - 3s 15ms/step - loss: 8.9521e-04 - accuracy: 0.9996 - val_loss: 0.1682 - val_accuracy: 0.9849
# Epoch 93/150
# 216/216 [==============================] - 3s 16ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.1872 - val_accuracy: 0.9791
# Epoch 94/150
# 216/216 [==============================] - 3s 16ms/step - loss: 5.2422e-04 - accuracy: 1.0000 - val_loss: 0.1627 - val_accuracy: 0.9832
# Epoch 95/150
# 216/216 [==============================] - 3s 16ms/step - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.1989 - val_accuracy: 0.9797
# Epoch 96/150
# 216/216 [==============================] - 4s 16ms/step - loss: 6.1409e-04 - accuracy: 0.9997 - val_loss: 0.2026 - val_accuracy: 0.9814
# Epoch 97/150
# 216/216 [==============================] - 4s 16ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.2035 - val_accuracy: 0.9832
# Epoch 98/150
# 216/216 [==============================] - 4s 16ms/step - loss: 0.0054 - accuracy: 0.9987 - val_loss: 0.1590 - val_accuracy: 0.9838
# Epoch 99/150
# 216/216 [==============================] - 3s 16ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.1574 - val_accuracy: 0.9820
# Epoch 100/150
# 216/216 [==============================] - 4s 17ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.2728 - val_accuracy: 0.9774
# Epoch 101/150
# 216/216 [==============================] - 4s 16ms/step - loss: 0.0032 - accuracy: 0.9988 - val_loss: 0.1333 - val_accuracy: 0.9855
# Epoch 102/150
# 216/216 [==============================] - 4s 16ms/step - loss: 8.3732e-04 - accuracy: 0.9997 - val_loss: 0.1561 - val_accuracy: 0.9843
# Epoch 103/150
# 216/216 [==============================] - 4s 16ms/step - loss: 5.2505e-04 - accuracy: 0.9999 - val_loss: 0.1755 - val_accuracy: 0.9826
# Epoch 104/150
# 216/216 [==============================] - 4s 17ms/step - loss: 3.9138e-04 - accuracy: 1.0000 - val_loss: 0.1636 - val_accuracy: 0.9832
# Epoch 105/150
# 216/216 [==============================] - 4s 16ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.1758 - val_accuracy: 0.9838
# Epoch 106/150
# 216/216 [==============================] - 3s 16ms/step - loss: 0.0053 - accuracy: 0.9990 - val_loss: 0.2392 - val_accuracy: 0.9809
# Epoch 107/150
# 216/216 [==============================] - 3s 16ms/step - loss: 0.0041 - accuracy: 0.9987 - val_loss: 0.1961 - val_accuracy: 0.9832
# Epoch 108/150
# 216/216 [==============================] - 3s 16ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.1349 - val_accuracy: 0.9809
# Epoch 109/150
# 216/216 [==============================] - 4s 16ms/step - loss: 0.0044 - accuracy: 0.9991 - val_loss: 0.1308 - val_accuracy: 0.9814
# Epoch 110/150
# 216/216 [==============================] - 3s 16ms/step - loss: 0.0023 - accuracy: 0.9990 - val_loss: 0.2254 - val_accuracy: 0.9826
# Epoch 111/150
# 216/216 [==============================] - 4s 16ms/step - loss: 0.0040 - accuracy: 0.9986 - val_loss: 0.1604 - val_accuracy: 0.9832
# Epoch 112/150
# 216/216 [==============================] - 4s 16ms/step - loss: 0.0088 - accuracy: 0.9987 - val_loss: 0.1613 - val_accuracy: 0.9820
# Epoch 113/150
# 216/216 [==============================] - 4s 16ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.2281 - val_accuracy: 0.9791
# Epoch 114/150
# 216/216 [==============================] - 4s 16ms/step - loss: 0.0018 - accuracy: 0.9991 - val_loss: 0.1593 - val_accuracy: 0.9855
# Epoch 115/150
# 216/216 [==============================] - 4s 16ms/step - loss: 4.9397e-04 - accuracy: 0.9999 - val_loss: 0.1614 - val_accuracy: 0.9849
# Epoch 116/150
# 216/216 [==============================] - 4s 16ms/step - loss: 7.6255e-04 - accuracy: 0.9997 - val_loss: 0.1903 - val_accuracy: 0.9849
# Epoch 117/150
#  44/216 [=====>........................] - ETA: 2s - loss: 9.3912e-05 - accuracy: 1.0000

# %% [markdown]
# ## Comparison between the Models

# %%
svm_accuracy = accuracy   # accuracy variable for SVM
dnn_accuracy = accuracy2  # accuracy variable for DNN
cnn_accuracy = accuracy3  # accuracy variable for CNN

# Plotting
labels = ['SVM', 'DNN', 'CNN']
accuracies = [svm_accuracy, dnn_accuracy, cnn_accuracy]

plt.bar(labels, accuracies, color=['blue', 'green', 'red'])
plt.ylabel('Accuracy')
plt.title('Comparison of Model Accuracies')
plt.ylim([0, 1])  # Set the y-axis limit between 0 and 1 for accuracy
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# We discussed four main parts of this project
# - **Detection:** Primarily focused on identifying the occurrence of seizures.
#
# - **Prediction:** Aims to forecast seizures, allowing for proactive measures such as aborting the seizure and preventing accidents.
#
# - **Combined Ways:** Integrating various methods, like combining EEG and ECG, to enhance specificity and accuracy in seizure detection and prediction.
#
# - **Best Approach:** Closed-loop systems, which seamlessly combine detection and prediction strategies, allowing for real-time monitoring and responsive interventions.
#
# In essence, a comprehensive approach involves both detecting and predicting seizures, and combining various methods within closed-loop systems stands out as a promising and effective strategy to address emergency cases, prevent accidents, and improve overall specificity and accuracy in managing epilepsy.
#
# ## Result of Practical work
# Towards the end, due to the rapid response, I came to the realization that employing **SVM** is more advantageous for swift **detection**. However, for heightened accuracy and **prediction** scenarios, **CNN** prove to be more effective. Consequently, my decision is to utilize  **CNN** for this specific dataset.

# %% [markdown]
# ## References

# %% [markdown]
# [1] 1mg. (n.d.). National Epilepsy Day: 7 Common Epilepsy Myths Busted. Retrieved from 1mg: https://www.1mg.com/articles/national-epilepsy-day-7-common-epilepsy-myths-busted/ on [20.01.2024].
#
# [2] Cure Epilepsy. (n.d.). What Is Seizure? Retrieved from Cure Epilepsy: https://www.cureepilepsy.org/for-patients/understanding/basics/what-is-seizure/ on [03.01.2024].
#
# [3] ResearchGate. (n.d.). Sketch of how to record an Electroencephalogram. Retrieved from ResearchGate: https://www.researchgate.net/figure/Sketch-of-how-to-record-an-Electroencephalogram-An-EEG-allows-measuring-the-electrical_fig1_338423585 on [31.01.2024].
#
#
# [4] Kaggle. (n.d.). Machine Learning Algorithms for Epileptic Seizures. Retrieved from Kaggle: https://www.kaggle.com/code/myustips/machine-learning-algorithms-for-epileptic-seizures on [18.12.2023].
#
# [5] Fisher RS, van Emde Boas W, Blume W, Elger C, Genton P, Lee P, Engel J Jr. Epileptic seizures and epilepsy: definitions proposed by the International League Against Epilepsy (ILAE) and the
# International Bureau for Epilepsy (IBE). Epilepsia. 2005 Apr;46(4):470-2. doi: 10.1111/j.0013-9580.2005.66104.x. PMID: 15816939
#
# [6] Epilepsy Foundation. (n.d.). Seizure Types. Retrieved from Epilepsy Foundation: https://www.epilepsy.com/what-is-epilepsy/seizure-types on [01.02.2024].
#
# [7] Ramgopal, Sriram, et al. "Seizure detection, seizure prediction, and closed-loop warning systems in epilepsy." Epilepsy & behavior 37 (2014): 291-307.
#
# [8] Verywell Health. (n.d.). What Is an EEG Test and What Is It Used For? Retrieved from Verywell Health: https://www.verywellhealth.com/what-is-an-eeg-test-and-what-is-it-used-for-3014879 on [29.01.2024].
#
# [9] American Association of Neurological Surgeons (AANS). (n.d.). Epilepsy Electrocorticography. Retrieved from AANS: https://www.aans.org/Patients/Neurosurgical-Conditions-and-Treatments/Epilepsy%20Electrocorticography on [31.01.2024].
#
# [10] Mayo Clinic. (n.d.). Electrocardiogram (EKG or ECG). Retrieved from Mayo Clinic: https://www.mayoclinic.org/tests-procedures/ekg/about/pac-20384983#dialogId13492854 on [31.01.2024].
#
#
# [11] Burgess, Richard C. "Automatic seizure detection by ECG analysis." Handbook of Clinical Neurophysiology 3 (2003): 167-177.
#
# [12] Kavanagh, Justin J., and Hylton B. Menz. "Accelerometry: a technique for quantifying movement patterns during walking." Gait & posture 28.1 (2008): 1-15.
#
# [13] Schulze-Bonhage A, Sales F, Wagner K, Teotonio R, Carius A, Schelle A, et al. Views
# of patients with epilepsy on seizure prediction devices. Epilepsy Behav
# 2010;18:388–96.
#
# [14] UPF Digital Repository. (n.d.). [Title of the specific dataset]. Retrieved from UPF Digital Repository: https://repositori.upf.edu/handle/ [specific dataset URL] on [22.11.2023].
#
# [15] UPF Digital Repository. (n.d.). [Title of the specific dataset]. Retrieved from UPF Digital Repository: https://repositori.upf.edu/handle/ [specific dataset URL] on [22.11.2023].
#
# [16] Handa, Palak, Monika Mathur, and Nidhi Goel. "Open and free EEG datasets for epilepsy diagnosis." arXiv preprint arXiv:2108.01030 (2021).
#
# [17] Andrzejak, Ralph G., et al. "Indications of nonlinear deterministic and finite-dimensional structures in time series of brain electrical activity: Dependence on recording region and brain state." Physical Review E 64.6 (2001): 061907.
#
# [18] Kaggle. (n.d.). Epileptic Seizure Recognition. Retrieved from Kaggle: https://www.kaggle.com/datasets/harunshimanto/epileptic-seizure-recognition/data on [09.11.2023].
